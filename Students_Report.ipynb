# %% [markdown]
# # 1. Import Pandas and Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. Load the CSV Dataset

# %%
df = pd.read_csv("Student_Dataset.csv")
df
# Out:
#     Student_ID           Name  Age            Course  Marks  \
# 0         1001   Aarav Sharma   19      Data Science   87.0
# 1         1002      Zoya Khan   20                AI   92.0
# 2         1003    Rohan Mehta   18  Computer Science   76.0
# 3         1004   Ananya Singh   21      Data Science   81.0
# 4         1005      Kabir Ali   19                AI   69.0
# 5         1006   Ishita Gupta   20  Computer Science   88.0
# 6         1007   Aditya Verma   22      Data Science   95.0
# 7         1008     Sara Ahmed   19                AI   73.0
# 8         1009     Arjun Nair   18  Computer Science   84.0
# 9         1010     Mehak Bhat   21      Data Science   79.0
# 10        1011  Vivaan Kapoor   20                AI   91.0
# 11        1012      Aisha Mir   19  Computer Science   68.0
# 12        1013      Rahul Das   23      Data Science   72.0
# 13        1014     Sana Malik   18                AI   89.0
# 14        1015    Karan Joshi   20  Computer Science   77.0
# ...

# %% [markdown]
# # 3. Display the First & Last Few Rows

# %%
df.head()
# Out:
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
#
#    Attendance_Percentage      City
# 0                   91.0  Srinagar
# 1                   95.0     Delhi
# 2                   82.0    Mumbai
# 3                   88.0  Srinagar
# 4                   76.0   Lucknow

# %%
df.tail()
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 20        1021    Aman Kumar   18  Computer Science   74.0
# 21        1022    Alina Shah   19      Data Science   96.0
# 22        1023   Nikhil Sood   22                AI   78.0
# 23        1024   Maryam Khan   20  Computer Science   85.0
# 24        1025  Reyansh Jain   21      Data Science   80.0
#
#     Attendance_Percentage       City
# 20                   78.0      Delhi
# 21                   98.0   Srinagar
# 22                   83.0       Pune
# 23                   88.0  Hyderabad
# 24                   84.0    Kolkata

# %% [markdown]
# # 5. Display Random Samples

# %%
df.sample(5)
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 7         1008    Sara Ahmed   19                AI   73.0
# 2         1003   Rohan Mehta   18  Computer Science   76.0
# 13        1014    Sana Malik   18                AI   89.0
# 17        1018     Manya Rao   22  Computer Science   70.0
# 0         1001  Aarav Sharma   19      Data Science   87.0
#
#     Attendance_Percentage       City
# 7                     NaN  Hyderabad
# 2                    82.0     Mumbai
# 13                   92.0        NaN
# 17                   74.0  Bengaluru
# 0                    91.0   Srinagar

# %%
df.sample(10)
# Out:
#     Student_ID          Name  Age            Course  Marks  \
# 14        1015   Karan Joshi   20  Computer Science   77.0
# 16        1017     Dev Patel   19                AI   86.0
# 22        1023   Nikhil Sood   22                AI   78.0
# 12        1013     Rahul Das   23      Data Science   72.0
# 6         1007  Aditya Verma   22      Data Science   95.0
# 3         1004  Ananya Singh   21      Data Science   81.0
# 15        1016   Hiba Sheikh   21      Data Science   94.0
# 1         1002     Zoya Khan   20                AI   92.0
# 4         1005     Kabir Ali   19                AI   69.0
# 7         1008    Sara Ahmed   19                AI   73.0
#
#     Attendance_Percentage        City
# 14                   85.0  Chandigarh
# 16                   89.0   Ahmedabad
# 22                   83.0        Pune
# 12                   81.0     Kolkata
# 6                    97.0        Pune
# 3                    88.0    Srinagar
# 15                   96.0    Srinagar
# ...

# %% [markdown]
# # 6. Check the Shape of the Dataset

# %%
df.shape
# Out:
# (25, 7)

# %% [markdown]
# # 7. Display Column Names

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage',
#        'City'],
#       dtype='object')

# %% [markdown]
# # 8. Display the Dataset Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %% [markdown]
# # 9. Check Data Types

# %%
df.dtypes
# Out:
# Student_ID                 int64
# Name                      object
# Age                        int64
# Course                    object
# Marks                    float64
# Attendance_Percentage    float64
# City                      object
# dtype: object

# %% [markdown]
# # 10. Get Complete Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             25 non-null     int64
#  1   Name                   25 non-null     object
#  2   Age                    25 non-null     int64
#  3   Course                 25 non-null     object
#  4   Marks                  24 non-null     float64
#  5   Attendance_Percentage  24 non-null     float64
#  6   City                   24 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# # 11. Generate Descriptive Statistics

# %%
df.describe()
# Out:
#         Student_ID        Age      Marks  Attendance_Percentage
# count    25.000000  25.000000  24.000000              24.000000
# mean   1013.000000  20.000000  82.250000              87.083333
# std       7.359801   1.414214   8.689074               7.252686
# min    1001.000000  18.000000  68.000000              72.000000
# 25%    1007.000000  19.000000  75.500000              82.750000
# 50%    1013.000000  20.000000  82.500000              88.000000
# 75%    1019.000000  21.000000  89.250000              92.250000
# max    1025.000000  23.000000  96.000000              98.000000

# %% [markdown]
# # 12. Generate Statistics for All Columns

# %%
df.describe(include="all")
# Out:
#          Student_ID          Name        Age        Course      Marks  \
# count     25.000000            25  25.000000            25  24.000000
# unique          NaN            25        NaN             3        NaN
# top             NaN  Aarav Sharma        NaN  Data Science        NaN
# freq            NaN             1        NaN             9        NaN
# mean    1013.000000           NaN  20.000000           NaN  82.250000
# std        7.359801           NaN   1.414214           NaN   8.689074
# min     1001.000000           NaN  18.000000           NaN  68.000000
# 25%     1007.000000           NaN  19.000000           NaN  75.500000
# 50%     1013.000000           NaN  20.000000           NaN  82.500000
# 75%     1019.000000           NaN  21.000000           NaN  89.250000
# max     1025.000000           NaN  23.000000           NaN  96.000000
#
#         Attendance_Percentage      City
# count               24.000000        24
# unique                    NaN        13
# ...

# %% [markdown]
# # 13. Check Missing Values

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Name                     0
# Age                      0
# Course                   0
# Marks                    1
# Attendance_Percentage    1
# City                     1
# dtype: int64

# %% [markdown]
# # 14. Check Whether Missing Values Exist

# %%
if df.isnull().values.any():
    print("Missing values are present in the dataset.")
else:
    print("No missing values are present in the dataset.")
# Out:
# Missing values are present in the dataset.

# %% [markdown]
# # 15. Calculate Missing Value Percentage

# %%
# Calculate percentage of missing values
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("Missing Value Percentage:")
print(missing_percentage)
# Out:
# Missing Value Percentage:
# Student_ID               0.0
# Name                     0.0
# Age                      0.0
# Course                   0.0
# Marks                    4.0
# Attendance_Percentage    4.0
# City                     4.0
# dtype: float64

# %% [markdown]
# # 16. Check Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 17. Check Unique Values

# %%
df.nunique()
# Out:
# Student_ID               25
# Name                     25
# Age                       6
# Course                    3
# Marks                    24
# Attendance_Percentage    22
# City                     13
# dtype: int64

# %% [markdown]
# # 18. Display Column-Wise Information

# %%
summary = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.values,
    "Missing Values": df.isnull().sum().values,
    "Unique Values": df.nunique().values
})
summary
# Out:
#                   Column Data Type  Missing Values  Unique Values
# 0             Student_ID     int64               0             25
# 1                   Name    object               0             25
# 2                    Age     int64               0              6
# 3                 Course    object               0              3
# 4                  Marks   float64               1             24
# 5  Attendance_Percentage   float64               1             22
# 6                   City    object               1             13
